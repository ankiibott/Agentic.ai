# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI 
 
load_dotenv()
# Out:
# True

# %%
#Calling LLM MODEL using Googlecloud

# %%
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")
response = llm.invoke("How many moons does Jupiter have?")
print(response.text)
# Out:
# Jupiter has **95 officially recognized moons**.
#
# This number can change as astronomers discover new, smaller moons using more powerful telescopes. The most famous of these are the four largest, known as the **Galilean moons**: Io, Europa, Ganymede, and Callisto.

# %%
#one line response
response = llm.invoke([
    ["system","answers in one short line"],
    ["human","How many moons does Jupiter have?"]
])
print(response.text)
# Out:
# Jupiter has 95 moons.

# %%
prompt = "Write a single tagline for a quirky coffee shop. Only output the tagline, nothing else"
# rigit answer, highest probability
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash",temperature = 0)
response = llm.invoke(prompt)
print(response.text)
# Out:
# Brewing the wonderfully weird.

# %%
#flatten answer 
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash",temperature = 1)
response = llm.invoke(prompt)
print(response.text)
# Out:
# Drink outside the lines.

# %%
#CALLING LLM MoDEL using GroqCloud

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="qwen/qwen3-32b", reasoning_format="parsed")

messages = [
    (
        "system",
        "You are a helpful assistant that gives a short answer to a question",
    ),
    (
        "human", 
        "How many moons does Jupiter have?"
    ),
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# Jupiter has **95 confirmed moons** as of the latest count, making it the planet with the most moons in our solar system.
